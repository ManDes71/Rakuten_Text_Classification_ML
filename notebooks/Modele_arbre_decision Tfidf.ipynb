# %% [markdown]
# <a href="https://colab.research.google.com/github/ManDes71/Rakuten_Text_Classification_ML/blob/main/notebooks/Modele_arbre_decision%20Tfidf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a***Google Colab -> Cette cellule est à executer (1 fois) pour le cloner le dépot en local***
# il est possible que google colab vous demande re demarrer la session

# %%
# !git clone https://github.com/ManDes71/Rakuten_Text_Classification_ML.git

# %% [markdown]
# ***Google Colab -> Cette cellule est à executer (2 fois) pour installer les bibliothèques nécessaires***
# You must restart the runtime in order to use newly installed versions

# %%
import sys
sys.path.append('/content/Rakuten_Text_Classification_ML/src')

# !pip install -r /content/Rakuten_Text_Classification_ML/requirements.txt

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize.regexp import RegexpTokenizer
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn import model_selection
from sklearn.metrics import f1_score, make_scorer

import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
# set the max columns to none
pd.set_option('display.max_columns', None)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shaky\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shaky\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import configparser
import sys
sys.path.append('../src')
#sys.path.append('/content/Rakuten_Text_Classification_ML/src')
import Bibli_DataScience_3_1 as ds
config = configparser.ConfigParser()
config.read('Rakuten_config_colab.ini')
# Out:
# section :  ['DOSSIER', 'FICHIER']
# []

# %%
import pandas as pd

# lecture des données sources d'entrainement
df_feats=pd.read_csv(ds.get_RACINE_DOSSIER() + 'X_train_update.csv')

# lecture des données cibles d'entrainement
df_target=pd.read_csv(ds.get_RACINE_DOSSIER() + 'Y_train_CVw08PX.csv')


# création d'un dataframe globale -  jointure
df=df_feats.merge(df_target,on='Unnamed: 0',how='inner')
df.rename(columns={'Unnamed: 0': 'Id'}, inplace=True)

# récupération du fichier df_langue.csv
df_langue=pd.read_csv(ds.get_RACINE_DOSSIER() + 'df_langue.csv')
df=df.merge(df_langue.drop(['Unnamed: 0','prdtypecode'], axis=1),on='Id',how='inner')
df_feats['PAYS_LANGUE'] = df['PAYS_LANGUE']


Lcat=df_target.sort_values(by='prdtypecode')['prdtypecode'].unique()


nomenclature=pd.read_csv(ds.get_RACINE_DOSSIER() + 'NOMENCLATURE.csv',header=0,encoding='utf-8',sep=';',index_col=0)
catdict=nomenclature.to_dict()['definition']

#
stopwordFR = pd.read_csv(ds.get_RACINE_DOSSIER() + 'stopwords_FR_02.csv')
stop_words = stopwordFR['MOT'].tolist()

# %%
df_feats
# Out:
#        Unnamed: 0                                        designation  \
# 0               0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1               1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2               2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3               3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4               4                               La Guerre Des Tuques
# ...           ...                                                ...
# 84911       84911                        The Sims [ Import Anglais ]
# 84912       84912  Kit piscine acier NEVADA déco pierre Ø 3.50m x...
# 84913       84913  Journal Officiel De La Republique Francaise N°...
# 84914       84914  Table Basse Bois De Récupération Massif Base B...
# 84915       84915  Gomme De Collection 2 Gommes Pinguin Glace Ver...
#
#                                              description   productid  \
# 0                                                    NaN  3804725264
# 1                                                    NaN   436067568
# 2      PILOT STYLE Touch Pen de marque Speedlink est ...   201115110
# 3                                                    NaN    50418756
# 4      Luc a des id&eacute;es de grandeur. Il veut or...   278535884
# ...                                                  ...         ...
# 84911                                                NaN   206719094
# 84912  <b>Description complète :</b><br />Kit piscine...  3065095706
# 84913                                                NaN   440707564
# 84914  <p>Cette table basse a un design unique et con...  3942400296
# 84915                                                NaN    57203227
#
#           imageid PAYS_LANGUE
# 0      1263597046          de
# 1      1008141237          fr
# 2       938777978          fr
# 3       457047496          de
# 4      1077757786          fr
# ...           ...         ...
# 84911   941495734          en
# 84912  1188462883          fr
# 84913  1009325617          fr
# 84914  1267353403          fr
# 84915   684671297          fr
#
# [84916 rows x 6 columns]

# %%
df_target
# Out:
#        Unnamed: 0  prdtypecode
# 0               0           10
# 1               1         2280
# 2               2           50
# 3               3         1280
# 4               4         2705
# ...           ...          ...
# 84911       84911           40
# 84912       84912         2583
# 84913       84913         2280
# 84914       84914         1560
# 84915       84915         2522
#
# [84916 rows x 2 columns]

# %% [markdown]
# *préprocessing utilisé :*
#  1. concaténation des champs "désignation" et "description"
#  2. traitement des phrases avec une expression régulière :  `r = re.compile(r"[a-zA-Z0-9âéè°]{2,}")`
# 	 on ne garde	que certains caractères et les mots d'au moins 2 caractères
#  3.  on découpe chaque phrase en une liste de mots : word_tokenize
#  4.  on met tous les mots de la phrase en minuscule
#  5.  on retire les stopswords par langue en utilisant le module nltk.corpus

# %%
def combine_description_and_designation(row):
    partie_design = row['designation'] if isinstance(row['designation'], str) else ''
    partie_descrip = row['description'] if isinstance(row['description'], str) else ''
    return partie_design + ' ' + partie_descrip if len(partie_descrip) > 0 else partie_design

# Appliquer la fonction à chaque ligne
df_feats['design_descrip'] = df_feats.apply(combine_description_and_designation, axis=1)

# %%
def clean_sentence(sentence,langue):
        if langue == 'en':
            SW = stopwords.words('english')
        elif langue == 'fr':
            SW = stopwords.words('french')
        elif langue == 'de':
            SW = stopwords.words('german')
        elif langue == 'ca':
            SW = stopwords.words('french')
        elif langue == 'nl':
            SW = stopwords.words('dutch')
        elif langue == 'it':
            SW = stopwords.words('italian')
        elif langue == 'es':
            SW = stopwords.words('spanish')
        else:
            SW = stopwords.words('french')
         # Pour chaque mot de la phrase (dans l'ordre inverse)
        for i, word in reversed(list(enumerate(sentence))):
                # Si le mot est un stopword
                if word in SW :
                    # On l'enlève de l'artikle
                    sentence.pop(i)
        return sentence
def dictionarize(article,langue):
        r = re.compile(r"[a-zA-Z0-9âéè°]{2,}")
        #dico ={}
        ListMots =[]
        sent = ' '.join(r.findall(article))
        ## Etape 3: Découper chaque phrase en une liste de mots
        sent = word_tokenize(sent)
        ## Etape 4: Mettre tous les mots de la phrase en minuscule
        sent_lower = [word.lower() for word in sent]
        ## Etape 5: Retirer les stopwords de chaque liste.
        sent_clean = clean_sentence(sent_lower,langue)
        #dico[i]=sent_clean
        ListMots.append(sent_clean)
        resultat = []

        for sous_liste in ListMots:
            resultat.extend(sous_liste)

        return resultat
def decomposition(article,langue):

        artikle = dictionarize(article,langue)
        artikle = [mot for mot in artikle if mot not in stop_words]

        return artikle

# %%
df_feats['phrases'] = df_feats.apply(lambda x :decomposition(str(x.design_descrip),str(x.PAYS_LANGUE)), axis=1)

# %% [markdown]
# ### 1er test : DecisionTreeClassifier() sans paramètres

# %%
X_train_avant, X_test_avant, y_train_avant, y_test_avant = train_test_split(df_feats, df_target, test_size=0.22, random_state=20,stratify=df_target['prdtypecode'])

X_train = X_train_avant['phrases'].apply(lambda x: ' '.join(x))
X_test = X_test_avant['phrases'].apply(lambda x: ' '.join(x))
y_train = y_train_avant['prdtypecode']
y_test = y_test_avant['prdtypecode']

# Créer un pipeline qui transforme les données, puis les adapte à un modèle LogisticRegression
text_clf = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase=True,max_df=0.8, min_df=2)),
    ('clf', DecisionTreeClassifier()),
])

# Entraînez le modèle
text_clf.fit(X_train, y_train)

# Testez le modèle sur l'ensemble de test
y_pred = text_clf.predict(X_test)

f1 = f1_score(y_test, y_pred, average='weighted')
print("F1 Score: ", f1)
accuracy = text_clf.score(X_test, y_test)
print("Accuracy: ", accuracy)
# Out:
# F1 Score:  0.7242730694855283
# Accuracy:  0.7222995396638475

# %%
# Obtenir tous les paramètres du pipeline
params = text_clf.get_params()

# Filtrer les paramètres pour obtenir seulement ceux relatifs à `RandomForestClassifier`
rf_params = {param_name: value for param_name, value in params.items() if 'clf__' in param_name}

print(rf_params)
# Out:
# {'clf__ccp_alpha': 0.0, 'clf__class_weight': None, 'clf__criterion': 'gini', 'clf__max_depth': None, 'clf__max_features': None, 'clf__max_leaf_nodes': None, 'clf__min_impurity_decrease': 0.0, 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__min_weight_fraction_leaf': 0.0, 'clf__random_state': None, 'clf__splitter': 'best'}

# %% [markdown]
# ### Grille de recherche
# Recherches des paramètres optimaux :
# **grille**  = {
#     'criterion': ['gini', 'entropy'],
#     'max_depth': [None],
#     'min_samples_split': [2, 3,4],
#     'class_weight': [None, 'balanced']
# }

# %%
X_train_avant, X_test_avant, y_train_avant, y_test_avant = train_test_split(df_feats, df_target, test_size=0.22, random_state=20,stratify=df_target['prdtypecode'])

X_train = X_train_avant['phrases'].apply(lambda x: ' '.join(x))
X_test = X_test_avant['phrases'].apply(lambda x: ' '.join(x))
y_train = y_train_avant['prdtypecode']
y_test = y_test_avant['prdtypecode']

# Créer un pipeline qui transforme les données, puis les adapte à un modèle DecisionTreeClassifier
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase=True,max_df=0.8, min_df=2)),
    ('clf', DecisionTreeClassifier()),
])

parametres =  {
    'clf__criterion': ['gini', 'entropy'],
    'clf__max_depth': [None],
    'clf__min_samples_split': [2, 3,4],
    'clf__class_weight': [None, 'balanced']
}

scorer = make_scorer(f1_score, average='weighted')
grid_search = model_selection.GridSearchCV(pipeline, param_grid=parametres,cv=5, scoring=scorer)
grille = grid_search.fit(X_train, y_train)
print("Meilleurs paramètres :", grid_search.best_params_)
print("Meilleur score F1 :", grid_search.best_score_)
y_pred = grid_search.predict(X_test)
# Out:
# Meilleurs paramètres : {'clf__class_weight': None, 'clf__criterion': 'gini', 'clf__max_depth': None, 'clf__min_samples_split': 3}
# Meilleur score F1 : 0.7135778949645477

# %% [markdown]
# **parametres** = {
#    'clf__C': [0.1, 1, 10],
#    'clf__max_iter': [200,300,500],
#    'clf__solver': ['lbfgs', 'liblinear'],
#    'clf__penalty': ['l1', 'l2', 'elasticnet', None]
# }
#     **Meilleurs paramètres** : {'clf__class_weight': None, 'clf__criterion': 'gini', 'clf__max_depth': None, 'clf__min_samples_split': 3}
# Meilleur score F1 :0.71357789496454774
# ​

# %% [markdown]
# ### Meilleur modèle

# %%
X_train_avant, X_test_avant, y_train_avant, y_test_avant = train_test_split(df_feats, df_target, test_size=0.22, random_state=20,stratify=df_target['prdtypecode'])

X_train = X_train_avant['phrases'].apply(lambda x: ' '.join(x))
X_test = X_test_avant['phrases'].apply(lambda x: ' '.join(x))
y_train = y_train_avant['prdtypecode']
y_test = y_test_avant['prdtypecode']

# Créer un pipeline qui transforme les données, puis les adapte à un modèle LogisticRegression
text_clf = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase=True,max_df=0.8, min_df=2)),
    ('clf', DecisionTreeClassifier(class_weight=None,criterion='gini',max_depth=None,min_samples_split= 3)),
])

# Entraînez le modèle
text_clf.fit(X_train, y_train)

# Testez le modèle sur l'ensemble de test
y_pred = text_clf.predict(X_test)

f1 = f1_score(y_test, y_pred, average='weighted')
print("F1 Score: ", f1)
accuracy = text_clf.score(X_test, y_test)
print("Accuracy: ", accuracy)
# Out:
# F1 Score:  0.7232579938393187
# Accuracy:  0.7211219355529387

# %% [markdown]
# F1 Score:  0.7232579938393187
# Accuracy:  0.7211219355529387

# %% [markdown]
# ### SAUVEGARDE DU MODELE

# %%
from joblib import dump
dump(text_clf, ds.get_RACINE_SAUVEGARDE() +'TreeDec_TfIdf.joblib')
# Out:
# ['E:/Manuel/PROJET/Rakuten_Text_Classification_ML/fichiers/TreeDec_TfIdf.joblib']

# %% [markdown]
# ### RECUPERATION DU MODELE

# %%
from joblib import load
text_clf = load(ds.get_RACINE_SAUVEGARDE() + 'TreeDec_TfIdf.joblib')

# %%
total=(y_pred  ==  y_test)

# %%
total.value_counts()
# Out:
# prdtypecode
# True     13472
# False     5210
# Name: count, dtype: int64

# %%
df_test = X_test_avant.merge(y_test_avant,on='Unnamed: 0',how='inner')
df_test['predict']=y_pred
df_test.head()
# Out:
#    Unnamed: 0                                        designation  \
# 0       48911                         Coffret 5 Pièces Peppa Pig
# 1       22412  Jacobs Lungo 8 Intenso Capsules De Café Compat...
# 2       19061  Eon Altar: Episode 2 - Whispers In The Catacom...
# 3       26343                                        D - Livre 1
# 4       67827  Tommee Tippee - 82037101 - Sangenic - Lot De 6...
#
#                                          description   productid     imageid  \
# 0  <p>Vaisselle pour le repas des tout-petits fab...  3900805892  1261630470
# 1  Ce lungo se caractérise par la torréfaction pr...  4056000876  1282290576
# 2  <div> <p> <strong>NOTE :</strong> un compte St...  2017625778  1120710502
# 3  Quand un jeune homme se retrouve projet&eacute...   688661390  1061771602
# 4  <br>Nouvelle recharge Tomme Tippee compatible ...   304796550   996077810
#
#   PAYS_LANGUE                                     design_descrip  \
# 0          fr  Coffret 5 Pièces Peppa Pig <p>Vaisselle pour l...
# 1          fr  Jacobs Lungo 8 Intenso Capsules De Café Compat...
# 2          fr  Eon Altar: Episode 2 - Whispers In The Catacom...
# 3          fr  D - Livre 1 Quand un jeune homme se retrouve p...
# 4          fr  Tommee Tippee - 82037101 - Sangenic - Lot De 6...
#
#                                              phrases  prdtypecode  predict
# 0  [coffret, pièces, peppa, pig, vaisselle, repas...         1320     1320
# 1  [jacobs, lungo, intenso, capsules, café, compa...         1940     1940
# 2  [eon, altar, episode, whispers, catacombs, ext...         2905     2905
# 3  [livre, jeune, homme, retrouve, projet, monde,...         2705     2705
# 4  [tommee, tippee, 82037101, sangenic, lot, nouv...         1320       50

# %% [markdown]
# ### Tableau des repartitions des **classes prédites** pour chaque **classe réelle**

# %%
for c in Lcat:
    print(c,'   ------   ', catdict[c] )
    print(df_test[df_test['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 10    ------    livres
# predict
# 10      0.570803
# 2403    0.110949
# 2705    0.091971
# 2280    0.090511
# 40      0.055474
# Name: proportion, dtype: float64
# 40    ------    jeux video pour pc et consoles
# predict
# 40      0.572464
# 10      0.103261
# 50      0.063406
# 1281    0.043478
# 2462    0.039855
# Name: proportion, dtype: float64
# 50    ------     accesoires jeux video
# predict
# 50      0.610811
# 2462    0.083784
# 40      0.040541
# 1281    0.029730
# 1560    0.027027
# Name: proportion, dtype: float64
# 60    ------    consoles de jeux video
# predict
# 60      0.770492
# 50      0.076503
# 2462    0.043716
# 1281    0.027322
# 40      0.021858
# Name: proportion, dtype: float64
# 1140    ------    produits derives “geeks” et figurines
# predict
# 1140    0.641156
# 1280    0.071429
# 10      0.045918
# 2280    0.034014
# 40      0.028912
# Name: proportion, dtype: float64
# 1160    ------    cartes collectionables
# predict
# 1160    0.883908
# 10      0.031034
# 2280    0.014943
# 1140    0.013793
# 40      0.011494
# Name: proportion, dtype: float64
# 1180    ------    figurines collectionables pour jeux de societe
# predict
# 1180    0.488095
# 10      0.077381
# 1281    0.071429
# 1140    0.071429
# 2403    0.053571
# Name: proportion, dtype: float64
# 1280    ------    jouets, peluches, poupees
# predict
# 1280    0.614379
# 1281    0.072829
# 1140    0.060691
# 1320    0.027077
# 1302    0.025210
# Name: proportion, dtype: float64
# 1281    ------    jeux de societe/cartes
# predict
# 1281    0.523077
# 1280    0.160440
# 40      0.048352
# 10      0.028571
# 1160    0.026374
# Name: proportion, dtype: float64
# 1300    ------    Petites voitures (jouets) et maquettes
# predict
# 1300    0.903604
# 1280    0.015315
# 2280    0.014414
# 10      0.010811
# 50      0.006306
# Name: proportion, dtype: float64
# 1301    ------    accesoires pour petis enfants/bebes et mobilier de jeu (flechettes, billard, babyfoot)
# predict
# 1301    0.730337
# 1281    0.044944
# 1560    0.039326
# 1302    0.033708
# 1280    0.028090
# Name: proportion, dtype: float64
# 1302    ------    jeux d'exterieur
# predict
# 1302    0.642336
# 1280    0.067518
# 1281    0.045620
# 1560    0.031022
# 2583    0.029197
# Name: proportion, dtype: float64
# 1320    ------    sacs pour femmes et accesore petite enfance
# predict
# 1320    0.643759
# 1280    0.054698
# 2060    0.042076
# 10      0.035063
# 1560    0.029453
# Name: proportion, dtype: float64
# 1560    ------    Mobilier et produits decoration/rangement pour la maison
# predict
# 1560    0.678315
# 2060    0.080645
# 2582    0.051075
# 2522    0.033154
# 2585    0.028674
# Name: proportion, dtype: float64
# 1920    ------    linge de maison (cousins, rideaux, serviettes, nappes, draps)
# predict
# 1920    0.852165
# 1560    0.048574
# 2060    0.035903
# 2582    0.008448
# 1320    0.008448
# Name: proportion, dtype: float64
# 1940    ------    nouriture (cafes,infusions,conserves, epices,etc)
# predict
# 1940    0.632768
# 10      0.045198
# 2522    0.033898
# 2583    0.033898
# 1280    0.028249
# Name: proportion, dtype: float64
# 2060    ------    lampes et accesoires decoration pour maison
# predict
# 2060    0.691257
# 1560    0.069217
# 1920    0.034608
# 1320    0.031876
# 2582    0.026412
# Name: proportion, dtype: float64
# 2220    ------    accesoires mascots/pets
# predict
# 2220    0.613260
# 1280    0.055249
# 2585    0.044199
# 1560    0.038674
# 1320    0.033149
# Name: proportion, dtype: float64
# 2280    ------    magazines
# predict
# 2280    0.708691
# 10      0.106017
# 2403    0.075454
# 2705    0.025788
# 40      0.014327
# Name: proportion, dtype: float64
# 2403    ------    livres et bds
# predict
# 2403    0.666667
# 2280    0.103810
# 10      0.100952
# 2705    0.024762
# 2522    0.021905
# Name: proportion, dtype: float64
# 2462    ------    consoles de jeux video et jeux videos
# predict
# 2462    0.626198
# 50      0.089457
# 40      0.083067
# 1281    0.041534
# 2403    0.031949
# Name: proportion, dtype: float64
# 2522    ------    produits de papeterie et rangement bureau
# predict
# 2522    0.795993
# 2280    0.022769
# 1320    0.022769
# 2060    0.019126
# 1280    0.019126
# Name: proportion, dtype: float64
# 2582    ------    mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
# predict
# 2582    0.564912
# 1560    0.096491
# 2060    0.087719
# 2585    0.059649
# 1920    0.031579
# Name: proportion, dtype: float64
# 2583    ------    accesoires de piscine
# predict
# 2583    0.927427
# 2582    0.011131
# 2585    0.010240
# 1302    0.006233
# 10      0.005343
# Name: proportion, dtype: float64
# 2585    ------    outillage et accesoires pour jardinage
# predict
# 2585    0.588342
# 1560    0.058288
# 2060    0.051002
# 2582    0.049180
# 2583    0.043716
# Name: proportion, dtype: float64
# 2705    ------    bds et livres
# predict
# 2705    0.588138
# 10      0.196046
# 2403    0.052718
# 2280    0.051071
# 40      0.032949
# Name: proportion, dtype: float64
# 2905    ------    Jeu En téléchargement
# predict
# 2905    0.973958
# 1281    0.010417
# 1180    0.005208
# 1300    0.005208
# 40      0.005208
# Name: proportion, dtype: float64

# %% [markdown]
# ### Tableau croisé

# %%
df_cross=pd.crosstab(df_test['prdtypecode'], df_test['predict'],normalize='index')
df_cross
# Out:
# predict          10        40        50        60        1140      1160  \
# prdtypecode
# 10           0.570803  0.055474  0.004380  0.000000  0.010219  0.002920
# 40           0.103261  0.572464  0.063406  0.003623  0.018116  0.012681
# 50           0.010811  0.040541  0.610811  0.013514  0.018919  0.005405
# 60           0.005464  0.021858  0.076503  0.770492  0.010929  0.010929
# 1140         0.045918  0.028912  0.011905  0.000000  0.641156  0.025510
# 1160         0.031034  0.011494  0.000000  0.000000  0.013793  0.883908
# 1180         0.077381  0.035714  0.011905  0.000000  0.071429  0.017857
# 1280         0.022409  0.019608  0.011204  0.000934  0.060691  0.006536
# 1281         0.028571  0.048352  0.008791  0.002198  0.021978  0.026374
# 1300         0.010811  0.002703  0.006306  0.000000  0.004505  0.002703
# 1301         0.005618  0.005618  0.011236  0.000000  0.005618  0.000000
# 2280         0.708691  0.075454  0.000000  0.009551  0.003820  0.000955
# 2403         0.103810  0.666667  0.003810  0.021905  0.000000  0.000952
# 2462         0.009585  0.031949  0.626198  0.000000  0.000000  0.003195
# 2522         0.022769  0.013661  0.001821  0.795993  0.003643  0.004554
# 2582         0.005263  0.007018  0.000000  0.010526  0.564912  0.024561
# 2583         0.004452  0.003117  0.000890  0.004007  0.011131  0.927427
# 2585         0.012750  0.005464  0.000000  0.041894  0.049180  0.043716
# 2705         0.051071  0.052718  0.001647  0.008237  0.011532  0.001647
# 2905         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# predict          2585      2705      2905
# prdtypecode
# 10           0.001460  0.091971  0.000000
# 40           0.001812  0.012681  0.000000
# 50           0.008108  0.008108  0.002703
# 60           0.000000  0.000000  0.000000
# 1140         0.003401  0.010204  0.000000
# 1160         0.001149  0.004598  0.000000
# 1180         0.017857  0.000000  0.000000
# 1280         0.007470  0.003735  0.000000
# 1281         0.004396  0.019780  0.000000
# 1300         0.001802  0.002703  0.000000
# 1301         0.011236  0.000000  0.000000
# 1302         0.018248  0.012774  0.000000
# 1320         0.004208  0.012623  0.000000
# 1560         0.028674  0.001792  0.000000
# 1920         0.003168  0.003168  0.000000
# 1940         0.000000  0.022599  0.000000
# 2060         0.021858  0.004554  0.000000
# 2220         0.044199  0.005525  0.000000
# 2280         0.000000  0.025788  0.000000
# 2403         0.000000  0.024762  0.000000
# 2462         0.000000  0.009585  0.000000
# 2522         0.010929  0.002732  0.000000
# 2582         0.059649  0.007018  0.000000
# 2583         0.010240  0.001781  0.000000
# 2585         0.588342  0.009107  0.000000
# 2705         0.003295  0.588138  0.000000
# 2905         0.000000  0.000000  0.973958

# %% [markdown]
# ### Tableau des repartitions des **classes prédites** pour chaque **classe réelle** avec libellés.

# %%
for c in Lcat:
    print(c,'   ------   ', catdict[c])
    s = df_cross.loc[c].sort_values(ascending=False)[:5]
    for index, value in s.items():  # Utilisez items() au lieu de iteritems()
        print(f"  : {index},  : {np.round(value*100,2)} % , {catdict[index]}")
# Out:
# 10    ------    livres
#   : 10,  : 57.08 % , livres
#   : 2403,  : 11.09 % , livres et bds
#   : 2705,  : 9.2 % , bds et livres
#   : 2280,  : 9.05 % , magazines
#   : 40,  : 5.55 % , jeux video pour pc et consoles
# 40    ------    jeux video pour pc et consoles
#   : 40,  : 57.25 % , jeux video pour pc et consoles
#   : 10,  : 10.33 % , livres
#   : 50,  : 6.34 % ,  accesoires jeux video
#   : 1281,  : 4.35 % , jeux de societe/cartes
#   : 2462,  : 3.99 % , consoles de jeux video et jeux videos
# 50    ------     accesoires jeux video
#   : 50,  : 61.08 % ,  accesoires jeux video
#   : 2462,  : 8.38 % , consoles de jeux video et jeux videos
#   : 40,  : 4.05 % , jeux video pour pc et consoles
#   : 1281,  : 2.97 % , jeux de societe/cartes
#   : 1560,  : 2.7 % , Mobilier et produits decoration/rangement pour la maison
# 60    ------    consoles de jeux video
#   : 60,  : 77.05 % , consoles de jeux video
#   : 50,  : 7.65 % ,  accesoires jeux video
#   : 2462,  : 4.37 % , consoles de jeux video et jeux videos
% , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2585,  : 1.02 % , outillage et accesoires pour jardinage
#   : 1302,  : 0.62 % , jeux d'exterieur
#   : 10,  : 0.53 % , livres
# 2585    ------    outillage et accesoires pour jardinage
#   : 2585,  : 58.83 % , outillage et accesoires pour jardinage
#   : 1560,  : 5.83 % , Mobilier et produits decoration/rangement pour la maison
#   : 2060,  : 5.1 % , lampes et accesoires decoration pour maison
#   : 2582,  : 4.92 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2583,  : 4.37 % , accesoires de piscine
# 2705    ------    bds et livres
#   : 2705,  : 58.81 % , bds et livres
#   : 10,  : 19.6 % , livres
#   : 2403,  : 5.27 % , livres et bds
#   : 2280,  : 5.11 % , magazines
#   : 40,  : 3.29 % , jeux video pour pc et consoles
# 2905    ------    Jeu En téléchargement
#   : 2905,  : 97.4 % , Jeu En téléchargement
#   : 1281,  : 1.04 % , jeux de societe/cartes
#   : 1180,  : 0.52 % , figurines collectionables pour jeux de societe
#   : 1300,  : 0.52 % , Petites voitures (jouets) et maquettes
#   : 40,  : 0.52 % , jeux video pour pc et consoles

# %% [markdown]
# ### Rapport de classification

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred ))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.39      0.57      0.46       685
#           40       0.57      0.57      0.57       552
#           50       0.59      0.61      0.60       370
#           60       0.91      0.77      0.83       183
#         1140       0.66      0.64      0.65       588
#         1160       0.86      0.88      0.87       870
#         1180       0.62      0.49      0.55       168
#         1280       0.63      0.61      0.62      1071
#         1281       0.47      0.52      0.49       455
#         1300       0.91      0.90      0.91      1110
#         1301       0.84      0.73      0.78       178
#         1302       0.69      0.64      0.67       548
#         1320       0.67      0.64      0.66       713
#         1560       0.69      0.68      0.69      1116
#         1920       0.86      0.85      0.86       947
#         1940       0.72      0.63      0.67       177
#         2060       0.68      0.69      0.69      1098
#         2220       0.73      0.61      0.66       181
#         2280       0.66      0.71      0.69      1047
#         2403       0.68      0.67      0.67      1050
#         2462       0.69      0.63      0.65       313
#         2522       0.80      0.80      0.80      1098
#         2582       0.60      0.56      0.58       570
#         2583       0.94      0.93      0.94      2246
#         2585       0.65      0.59      0.62       549
#         2705       0.64      0.59      0.61       607
#         2905       0.99      0.97      0.98       192
#
#     accuracy                           0.72     18682
#    macro avg       0.71      0.69      0.70     18682
# weighted avg       0.73      0.72      0.72     18682

# %% [markdown]
# ### Matrice de confusion

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred )
print(cm[:10,:10])
print('*************************************************')
print(cm[10:20,10:20])
print('*************************************************')
print(cm[20:,20:])
# Out:
# [[ 391   38    3    0    7    2    6   10    5    4]
#  [  57  316   35    2   10    7    1   17   24    5]
#  [   4   15  226    5    7    2    2    7   11    4]
#  [   1    4   14  141    2    2    0    1    5    1]
#  [  27   17    7    0  377   15    5   42    6    3]
#  [  27   10    0    0   12  769    1    5    9    1]
#  [  13    6    2    0   12    3   82    6   12    1]
#  [  24   21   12    1   65    7    2  658   78   23]
#  [  13   22    4    1   10   12    5   73  238    2]
#  [  12    3    7    0    5    3    1   17    2 1003]]
# *************************************************
# [[130   6   3   7   0   1   1   1   2   1]
#  [  4 352  13  17   3   2   4   3   4   4]
#  [  2  14 459  21  15   4  30   3  16  11]
#  [  0  16  23 757  26   5  90   3   3   6]
#  [  2   5   8  46 807   0  34   6   1   2]
#  [  1   4   3   1   1 112   4   1   5   5]
#  [  0   8  35  76  38   3 759   8   7   4]
#  [  0   2   6   7   1   1   6 111   1   2]
#  [  1   0   3   2   0   0   6   0 742  79]
#  [  0   3   4   2   1   1   5   3 109 700]]
# *************************************************
# [[ 196    0    0    1    0    3    0]
#  [   2  874    4    5   12    3    0]
#  [   0    6  322   14   34    4    0]
#  [   2    9   25 2083   23    4    0]
#  [   0   23   27   24  323    5    0]
#  [   1    5    7    1    2  357    0]
#  [   0    0    0    0    0    0  187]]

# %%
fig, ax = plt.subplots(figsize=(10,10))
cm_normalized = cm.astype('float') / (cm.sum(axis=1)[:, np.newaxis])
#cm_normalized=cm.div(cm.sum(axis=1), axis=0)
cax = ax.matshow(cm_normalized, cmap='Reds')
plt.xticks(range(27),catdict,rotation=90)
plt.yticks(range(27),catdict,rotation=0)
plt.show()

# %% [markdown]
# ## Etude des catégories 10 ; 2280 ; 2403 ; 2705

# %%
df_livres=df_test[df_test['prdtypecode'].isin([10,2280,2403,2705])]
vectorizer=text_clf.named_steps['tfidf']
df_livres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3389 entries, 3 to 18679
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      3389 non-null   int64
#  1   designation     3389 non-null   object
#  2   description     569 non-null    object
#  3   productid       3389 non-null   int64
#  4   imageid         3389 non-null   int64
#  5   PAYS_LANGUE     3389 non-null   object
#  6   design_descrip  3389 non-null   object
#  7   phrases         3389 non-null   object
#  8   prdtypecode     3389 non-null   int64
#  9   predict         3389 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 291.2+ KB

# %% [markdown]
# ### Tableau des repartitions des **classes predites** pour chaque `classe réelle`

# %%
for c in [10,2280,2403,2705]:
    print(c,'   ------   ', catdict[c] )
    print(df_livres[df_livres['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 10    ------    livres
# predict
# 10      0.570803
# 2403    0.110949
# 2705    0.091971
# 2280    0.090511
# 40      0.055474
# Name: proportion, dtype: float64
# 2280    ------    magazines
# predict
# 2280    0.708691
# 10      0.106017
# 2403    0.075454
# 2705    0.025788
# 40      0.014327
# Name: proportion, dtype: float64
# 2403    ------    livres et bds
# predict
# 2403    0.666667
# 2280    0.103810
# 10      0.100952
# 2705    0.024762
# 2522    0.021905
# Name: proportion, dtype: float64
# 2705    ------    bds et livres
# predict
# 2705    0.588138
# 10      0.196046
# 2403    0.052718
# 2280    0.051071
# 40      0.032949
# Name: proportion, dtype: float64

# %% [markdown]
# ### Les 10 mots ayant le **scores TF-IDF** les plus élévés et ceux des rangs de 76 à 80.
# Ces scores aident à identifier les mots qui sont importants dans un document particulier en tenant compte
# de leur fréquence dans ce document et de leur rareté dans l'ensemble du corpus.

# %%
Words = vectorizer.transform(df_livres['designation'])
#help(CountVectorizer)
words = vectorizer.get_feature_names_out()
word_counts = Words.sum(axis=0)
word_count_dict = dict(zip(words, word_counts.tolist()[0]))
#print(word_count_dict)
occurrences_triees = sorted(word_count_dict.items(), key=lambda x: x[1], reverse=True)[:80]
Dic_words={}
for item in occurrences_triees:
    #print(item[0], ":", item[1])
    Dic_words[item[0]]=item[1]
#print(Dic_words)
df_words=pd.DataFrame.from_dict(Dic_words, orient='index',columns=['Total'])
print(df_words.head(10))
print(df_words.tail())
# Out:
#               Total
# lot       93.297337
# tome      56.344146
# livres    51.999364
# 01        40.179128
# 10        38.497605
# 12        32.783278
# 11        30.922111
# france    30.095782
# revue     29.677567
# magazine  29.114804
#               Total
# piano      7.124548
# 24         7.036313
# avril      6.973697
# album      6.967048
# intégrale  6.873213

# %% [markdown]
# ### Les 20 mots ayant le **scores TF-IDF** les plus élévés .

# %%
df_total_livres=df_words
words = vectorizer.get_feature_names_out()
for c in [10,2705,2280,2403]:
    X_words = vectorizer.transform(df_livres[df_livres['prdtypecode']==c] ['designation'])
    word_counts = X_words.sum(axis=0)
    word_count_dict = dict(zip(words, word_counts.tolist()[0]))
    occurrences_triees = sorted(word_count_dict.items(), key=lambda x: x[1], reverse=True)[:20]
    Dic_words={}
    for item in occurrences_triees:
        Dic_words[item[0]]=item[1]
    df_words_X=pd.DataFrame.from_dict(Dic_words, orient='index',columns=[str(c)])
    df_total_livres=df_total_livres.join(df_words_X)
df_total_livres.head(20)
# Out:
#                 Total         10       2705       2280       2403
# lot         93.297337        NaN        NaN        NaN  92.158471
# tome        56.344146  11.650113  21.940619        NaN  21.325055
# livres      51.999364        NaN        NaN        NaN  50.275812
# 01          40.179128        NaN        NaN  36.974804        NaN
# 10          38.497605        NaN        NaN  19.536979  16.409545
# 12          32.783278        NaN        NaN  19.277957  12.077328
# 11          30.922111   3.646027        NaN  20.438734        NaN
# france      30.095782   3.912862        NaN  14.726065   9.712943
# revue       29.677567        NaN        NaN  16.593297  11.865593
# magazine    29.114804        NaN        NaN  20.411596        NaN
# tomes       28.600826        NaN        NaN        NaN  27.645146
# volumes     25.446771        NaN        NaN        NaN  24.227733
# histoire    24.697639   5.927844        NaN        NaN  11.732009
# journal     24.205332   2.485323        NaN  15.421089        NaN
# vie         21.952814   3.263573   7.939092   7.403071        NaN
# monde       20.874603        NaN   5.277999   8.893445        NaN
# collection  19.138294        NaN        NaN        NaN  15.550607
# 09          17.751484        NaN        NaN  17.751484        NaN
# revues      17.625920        NaN        NaN        NaN  17.391009
# paris       17.476187        NaN   3.879804  10.305815        NaN

# %% [markdown]
# ### Heatmap couleur Rouge foncée : fréquence très élévée
# couleur Bleu foncée : fréquance très basse
# couleur Blanche : NaN

# %%
fig, ax = plt.subplots(figsize=(2,20))
cax = ax.matshow(df_total_livres.iloc[0:40], cmap = 'coolwarm')
plt.xticks(range(5),('total','10','2705','2280','2403'),rotation=45)
plt.yticks(range(40),df_total_livres.iloc[0:40].index,rotation=0)
plt.show()

# %% [markdown]
# ## Etude des catégories 1280,1281

# %%
df_jouets=df_test[df_test['prdtypecode'].isin([1280,1281])]

# %% [markdown]
# ### Tableau des repartitions des **classes predites** pour chaque `classe réelle`

# %%
for c in [1280,1281]:
    print(c,'   ------   ', catdict[c] )
    print(df_jouets[df_jouets['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 1280    ------    jouets, peluches, poupees
# predict
# 1280    0.614379
# 1281    0.072829
# 1140    0.060691
# 1320    0.027077
# 1302    0.025210
# Name: proportion, dtype: float64
# 1281    ------    jeux de societe/cartes
# predict
# 1281    0.523077
# 1280    0.160440
# 40      0.048352
# 10      0.028571
# 1160    0.026374
# Name: proportion, dtype: float64

# %% [markdown]
# ### Les 10 mots ayant le **scores TF-IDF** les plus élévés et ceux des rangs de 76 à 80.
# Ces scores aident à identifier les mots qui sont importants dans un document particulier en tenant compte
# de leur fréquence dans ce document et de leur rareté dans l'ensemble du corpus.

# %%
Words = vectorizer.transform(df_jouets['designation'])
#help(CountVectorizer)
words = vectorizer.get_feature_names_out()
word_counts = Words.sum(axis=0)
word_count_dict = dict(zip(words, word_counts.tolist()[0]))
#print(word_count_dict)
occurrences_triees = sorted(word_count_dict.items(), key=lambda x: x[1], reverse=True)[:80]
Dic_words={}
for item in occurrences_triees:
    #print(item[0], ":", item[1])
    Dic_words[item[0]]=item[1]
#print(Dic_words)
df_words=pd.DataFrame.from_dict(Dic_words, orient='index',columns=['Total'])
print(df_words.head(10))
print(df_words.tail())
# Out:
#              Total
# enfants  45.267651
# jouet    37.558010
# peluche  35.140603
# jouets   34.989406
# toy      32.252619
# doudou   30.234269
# puzzle   27.056359
# jeu      23.825432
# bébé     21.655558
# cadeau   21.282932
#                   Total
# développement  5.803189
# boule          5.802947
# simulé         5.781250
# musique        5.724818
# jouer          5.718962

# %% [markdown]
# ### Les 20 mots ayant le **scores TF-IDF** les plus élévés .

# %%
df_total_jouets=df_words
words = vectorizer.get_feature_names_out()
for c in [1280,1281]:
    X_words = vectorizer.transform(df_jouets[df_jouets['prdtypecode']==c] ['designation'])
    word_counts = X_words.sum(axis=0)
    word_count_dict = dict(zip(words, word_counts.tolist()[0]))
    occurrences_triees = sorted(word_count_dict.items(), key=lambda x: x[1], reverse=True)[:20]
    Dic_words={}
    for item in occurrences_triees:
        Dic_words[item[0]]=item[1]
    df_words_X=pd.DataFrame.from_dict(Dic_words, orient='index',columns=[str(c)])
    df_total_jouets=df_total_jouets.join(df_words_X)
df_total_jouets.head(20)
# Out:
#              Total       1280       1281
# enfants  45.267651  33.080509  12.187142
# jouet    37.558010  29.292394   8.265616
# peluche  35.140603  32.579356        NaN
# jouets   34.989406  26.024941   8.964465
# toy      32.252619  22.019574  10.233046
# doudou   30.234269  30.234269        NaN
# puzzle   27.056359  22.612416   4.443943
# jeu      23.825432        NaN  19.169829
# bébé     21.655558  14.665426   6.990132
# cadeau   21.282932  15.821260   5.461672
# rc       20.587665  19.539490        NaN
# voiture  17.665365  15.301379        NaN
# game     16.973332        NaN  14.201457
# doll     16.902886  15.368207        NaN
# stress   14.992788   9.945964   5.046823
# baby     14.925936  13.489560        NaN
# slime    14.351219        NaN   7.479360
# poupée   14.285657  12.814163        NaN
# mini     14.269059        NaN        NaN
# modèle   13.781289  10.899263        NaN

# %% [markdown]
# ###**Heatmap**
# couleur Rouge foncée : fréquence très élévée
# couleur Bleu foncée : fréquance très basse
# couleur Blanche : NaN

# %%
fig, ax = plt.subplots(figsize=(2,20))
cax = ax.matshow(df_total_jouets.iloc[0:40], cmap = 'coolwarm')
plt.xticks(range(3),('total','1280','1281'),rotation=45)
plt.yticks(range(40),df_total_jouets.iloc[0:40].index,rotation=0)
plt.show()
