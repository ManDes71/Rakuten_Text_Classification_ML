# %% [markdown]
# <a href="https://colab.research.google.com/github/ManDes71/Rakuten_Text_Classification_ML/blob/main/notebooks/Modele_XGBClassifier%20Tfidf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a***Google Colab -> Cette cellule est à executer (1 fois) pour le cloner le dépot en local***
# il est possible que google colab vous demande re demarrer la session

# %%
# !git clone https://github.com/ManDes71/Rakuten_Text_Classification_ML.git

# %% [markdown]
# ***Google Colab -> Cette cellule est à executer (2 fois) pour installer les bibliothèques nécessaires***
# You must restart the runtime in order to use newly installed versions

# %%
import sys
sys.path.append('/content/Rakuten_Text_Classification_ML/src')

# !pip install -r /content/Rakuten_Text_Classification_ML/requirements.txt

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize.regexp import RegexpTokenizer
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from sklearn import model_selection
from sklearn.metrics import f1_score, make_scorer

import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
# set the max columns to none
pd.set_option('display.max_columns', None)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import configparser
import sys
sys.path.append('../src')
#sys.path.append('/content/Rakuten_Text_Classification_ML/src')
import Bibli_DataScience_3_1 as ds
config = configparser.ConfigParser()
config.read('Rakuten_config_colab.ini')
# Out:
# section :  ['DOSSIER', 'FICHIER']
# []

# %%
import pandas as pd

# lecture des données sources d'entrainement
df_feats=pd.read_csv(ds.get_RACINE_DOSSIER() + 'X_train_update.csv')

# lecture des données cibles d'entrainement
df_target=pd.read_csv(ds.get_RACINE_DOSSIER() + 'Y_train_CVw08PX.csv')


# création d'un dataframe globale -  jointure
df=df_feats.merge(df_target,on='Unnamed: 0',how='inner')
df.rename(columns={'Unnamed: 0': 'Id'}, inplace=True)

# récupération du fichier df_langue.csv
df_langue=pd.read_csv(ds.get_RACINE_DOSSIER() + 'df_langue.csv')
df=df.merge(df_langue.drop(['Unnamed: 0','prdtypecode'], axis=1),on='Id',how='inner')
df_feats['PAYS_LANGUE'] = df['PAYS_LANGUE']


Lcat=df_target.sort_values(by='prdtypecode')['prdtypecode'].unique()


nomenclature=pd.read_csv(ds.get_RACINE_DOSSIER() + 'NOMENCLATURE.csv',header=0,encoding='utf-8',sep=';',index_col=0)
catdict=nomenclature.to_dict()['definition']

#
stopwordFR = pd.read_csv(ds.get_RACINE_DOSSIER() + 'stopwords_FR_02.csv')
stop_words = stopwordFR['MOT'].tolist()

# %%
df_feats
# Out:
#        Unnamed: 0                                        designation  \
# 0               0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1               1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2               2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3               3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4               4                               La Guerre Des Tuques
# ...           ...                                                ...
# 84911       84911                        The Sims [ Import Anglais ]
# 84912       84912  Kit piscine acier NEVADA déco pierre Ø 3.50m x...
# 84913       84913  Journal Officiel De La Republique Francaise N°...
# 84914       84914  Table Basse Bois De Récupération Massif Base B...
# 84915       84915  Gomme De Collection 2 Gommes Pinguin Glace Ver...
#
#                                              description   productid  \
# 0                                                    NaN  3804725264
# 1                                                    NaN   436067568
# 2      PILOT STYLE Touch Pen de marque Speedlink est ...   201115110
# 3                                                    NaN    50418756
# 4      Luc a des id&eacute;es de grandeur. Il veut or...   278535884
# ...                                                  ...         ...
# 84911                                                NaN   206719094
# 84912  <b>Description complète :</b><br />Kit piscine...  3065095706
# 84913                                                NaN   440707564
# 84914  <p>Cette table basse a un design unique et con...  3942400296
# 84915                                                NaN    57203227
#
#           imageid PAYS_LANGUE
# 0      1263597046          de
# 1      1008141237          fr
# 2       938777978          fr
# 3       457047496          de
# 4      1077757786          ca
# ...           ...         ...
# 84911   941495734          en
# 84912  1188462883          fr
# 84913  1009325617          fr
# 84914  1267353403          fr
# 84915   684671297          fr
#
# [84916 rows x 6 columns]

# %%
df_target
# Out:
#        Unnamed: 0  prdtypecode
# 0               0           10
# 1               1         2280
# 2               2           50
# 3               3         1280
# 4               4         2705
# ...           ...          ...
# 84911       84911           40
# 84912       84912         2583
# 84913       84913         2280
# 84914       84914         1560
# 84915       84915         2522
#
# [84916 rows x 2 columns]

# %% [markdown]
# *préprocessing utilisé :*
#  1. concaténation des champs "désignation" et "description"
#  2. traitement des phrases avec une expression régulière :  `r = re.compile(r"[a-zA-Z0-9âéè°]{2,}")`
# 	 on ne garde	que certains caractères et les mots d'au moins 2 caractères
#  3.  on découpe chaque phrase en une liste de mots : word_tokenize
#  4.  on met tous les mots de la phrase en minuscule
#  5.  on retire les stopswords par langue en utilisant le module nltk.corpus

# %%
def combine_description_and_designation(row):
    partie_design = row['designation'] if isinstance(row['designation'], str) else ''
    partie_descrip = row['description'] if isinstance(row['description'], str) else ''
    return partie_design + ' ' + partie_descrip if len(partie_descrip) > 0 else partie_design

# Appliquer la fonction à chaque ligne
df_feats['design_descrip'] = df_feats.apply(combine_description_and_designation, axis=1)

# %%
def clean_sentence(sentence,langue):
        if langue == 'en':
            SW = stopwords.words('english')
        elif langue == 'fr':
            SW = stopwords.words('french')
        elif langue == 'de':
            SW = stopwords.words('german')
        elif langue == 'ca':
            SW = stopwords.words('french')
        elif langue == 'nl':
            SW = stopwords.words('dutch')
        elif langue == 'it':
            SW = stopwords.words('italian')
        elif langue == 'es':
            SW = stopwords.words('spanish')
        else:
            SW = stopwords.words('french')
         # Pour chaque mot de la phrase (dans l'ordre inverse)
        for i, word in reversed(list(enumerate(sentence))):
                # Si le mot est un stopword
                if word in SW :
                    # On l'enlève de l'artikle
                    sentence.pop(i)
        return sentence
def dictionarize(article,langue):
        r = re.compile(r"[a-zA-Z0-9âéè°]{2,}")
        #dico ={}
        ListMots =[]
        sent = ' '.join(r.findall(article))
        ## Etape 3: Découper chaque phrase en une liste de mots
        sent = word_tokenize(sent)
        ## Etape 4: Mettre tous les mots de la phrase en minuscule
        sent_lower = [word.lower() for word in sent]
        ## Etape 5: Retirer les stopwords de chaque liste.
        sent_clean = clean_sentence(sent_lower,langue)
        #dico[i]=sent_clean
        ListMots.append(sent_clean)
        resultat = []

        for sous_liste in ListMots:
            resultat.extend(sous_liste)

        return resultat
def decomposition(article,langue):

        artikle = dictionarize(article,langue)
        artikle = [mot for mot in artikle if mot not in stop_words]

        return artikle

# %%
df_feats['phrases'] = df_feats.apply(lambda x :decomposition(str(x.design_descrip),str(x.PAYS_LANGUE)), axis=1)

# %% [markdown]
# ### 1er test : XGBClassifier() sans paramètres

# %%
X_train_avant, X_test_avant, y_train_avant, y_test_avant = train_test_split(df_feats, df_target, test_size=0.22, random_state=20,stratify=df_target['prdtypecode'])

X_train = X_train_avant['phrases'].apply(lambda x: ' '.join(x))
X_test = X_test_avant['phrases'].apply(lambda x: ' '.join(x))
y_train = y_train_avant['prdtypecode']
y_test = y_test_avant['prdtypecode']

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Créer un pipeline qui transforme les données, puis les adapte à un modèle XGBClassifier
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase=True,max_df=0.8, min_df=2)),
    ('clf', xgb.XGBClassifier()),
])

# Entraînez le modèle
pipeline.fit(X_train, y_train_encoded)

# Testez le modèle sur l'ensemble de test
y_pred_classes = pipeline.predict(X_test)
y_pred = label_encoder.inverse_transform(y_pred_classes)
y_prob = pipeline.predict_proba(X_test)

f1 = f1_score(y_test, y_pred, average='weighted')
print("F1 Score: ", f1)
accuracy = pipeline.score(X_test,y_test_encoded)
print("Accuracy: ", accuracy)
# Out:
# F1 Score:  0.8064737884476054
# Accuracy:  0.7992720265496199

# %% [markdown]
# F1 Score:  0.8064737884476054
# Accuracy:  0.7992720265496199

# %%
# Obtenir tous les paramètres du pipeline
params = pipeline.get_params()

# Filtrer les paramètres pour obtenir seulement ceux relatifs à `RandomForestClassifier`
rf_params = {param_name: value for param_name, value in params.items() if 'clf__' in param_name}

print(rf_params)
# Out:
# {'clf__objective': 'multi:softprob', 'clf__use_label_encoder': None, 'clf__base_score': None, 'clf__booster': None, 'clf__callbacks': None, 'clf__colsample_bylevel': None, 'clf__colsample_bynode': None, 'clf__colsample_bytree': None, 'clf__early_stopping_rounds': None, 'clf__enable_categorical': False, 'clf__eval_metric': None, 'clf__feature_types': None, 'clf__gamma': None, 'clf__gpu_id': None, 'clf__grow_policy': None, 'clf__importance_type': None, 'clf__interaction_constraints': None, 'clf__learning_rate': None, 'clf__max_bin': None, 'clf__max_cat_threshold': None, 'clf__max_cat_to_onehot': None, 'clf__max_delta_step': None, 'clf__max_depth': None, 'clf__max_leaves': None, 'clf__min_child_weight': None, 'clf__missing': nan, 'clf__monotone_constraints': None, 'clf__n_estimators': 100, 'clf__n_jobs': None, 'clf__num_parallel_tree': None, 'clf__predictor': None, 'clf__random_state': None, 'clf__reg_alpha': None, 'clf__reg_lambda': None, 'clf__sampling_method': None, 'clf__scale_pos_weight': None, 'clf__subsample': None, 'clf__tree_method': None, 'clf__validate_parameters': None, 'clf__verbosity': None}

# %% [markdown]
# ### Grille de recherche
# Recherches des paramètres optimaux :
# **grille**  = {'clf__objective': 'multi:softprob', 'clf__use_label_encoder': None, 'clf__base_score': None, 'clf__booster': None, 'clf__callbacks': None, 'clf__colsample_bylevel': None, 'clf__colsample_bynode': None, 'clf__colsample_bytree': None, 'clf__early_stopping_rounds': None, 'clf__enable_categorical': False, 'clf__eval_metric': None, 'clf__feature_types': None, 'clf__gamma': None, 'clf__gpu_id': None, 'clf__grow_policy': None, 'clf__importance_type': None, 'clf__interaction_constraints': None, 'clf__learning_rate': None, 'clf__max_bin': None, 'clf__max_cat_threshold': None, 'clf__max_cat_to_onehot': None, 'clf__max_delta_step': None, 'clf__max_depth': None, 'clf__max_leaves': None, 'clf__min_child_weight': None, 'clf__missing': nan, 'clf__monotone_constraints': None, 'clf__n_estimators': 100, 'clf__n_jobs': None, 'clf__num_parallel_tree': None, 'clf__predictor': None, 'clf__random_state': None, 'clf__reg_alpha': None, 'clf__reg_lambda': None, 'clf__sampling_method': None, 'clf__scale_pos_weight': None, 'clf__subsample': None, 'clf__tree_method': None, 'clf__validate_parameters': None, 'clf__verbosity': None}

# %%
X_train_avant, X_test_avant, y_train_avant, y_test_avant = train_test_split(df_feats, df_target, test_size=0.22, random_state=20,stratify=df_target['prdtypecode'])

X_train = X_train_avant['phrases'].apply(lambda x: ' '.join(x))
X_test = X_test_avant['phrases'].apply(lambda x: ' '.join(x))
y_train = y_train_avant['prdtypecode']
y_test = y_test_avant['prdtypecode']

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Créer un pipeline qui transforme les données, puis les adapte à un modèle XGBClassifier
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase=True,max_df=0.8, min_df=2)),
    ('clf', xgb.XGBClassifier()),
])

parametres =  {
        'clf__max_depth': [3, 5, 7],
        'clf__learning_rate': [0.1, 0.01, 0.001],
        'clf__subsample': [0.5, 0.7, 1]
        }

scorer = make_scorer(f1_score, average='weighted')
grid_search = model_selection.GridSearchCV(pipeline, param_grid=parametres,cv=5, scoring=scorer)
grille = grid_search.fit(X_train, y_train_encoded)
print("Meilleurs paramètres :", grid_search.best_params_)
print("Meilleur score F1 :", grid_search.best_score_)
y_pred_classes = grid_search.predict(X_test)

y_pred = label_encoder.inverse_transform(y_pred_classes)
y_prob = pipeline.predict_proba(X_test)
# Out:
# Meilleurs paramètres : {'clf__learning_rate': 0.1, 'clf__max_depth': 7, 'clf__subsample': 0.7}
# Meilleur score F1 : 0.7867207475934078

# %% [markdown]
# **parametres** = {
#         'clf__max_depth': [3, 5, 7],
#         'clf__learning_rate': [0.1, 0.01, 0.001],
#         'clf__subsample': [0.5, 0.7, 1]
#         }
#     **Meilleurs paramètres** : {'clf__learning_rate': 0.1, 'clf__max_depth': 7, 'clf__subsample': 0.7}
# 0.78672074759340784
# ​

# %% [markdown]
# ### Meilleur modèle

# %%
X_train_avant, X_test_avant, y_train_avant, y_test_avant = train_test_split(df_feats, df_target, test_size=0.22, random_state=20,stratify=df_target['prdtypecode'])

X_train = X_train_avant['phrases'].apply(lambda x: ' '.join(x))
X_test = X_test_avant['phrases'].apply(lambda x: ' '.join(x))
y_train = y_train_avant['prdtypecode']
y_test = y_test_avant['prdtypecode']

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Créer un pipeline qui transforme les données, puis les adapte à un modèle XGBClassifier
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase=True,max_df=0.8, min_df=2)),
    ('clf', xgb.XGBClassifier(max_depth=None )),
])

# Entraînez le modèle
pipeline.fit(X_train, y_train_encoded)

# Testez le modèle sur l'ensemble de test
y_pred_classes = pipeline.predict(X_test)
y_pred = label_encoder.inverse_transform(y_pred_classes)
y_prob = pipeline.predict_proba(X_test)

f1 = f1_score(y_test, y_pred, average='weighted')
print("F1 Score: ", f1)
accuracy = pipeline.score(X_test, y_test_encoded)
print("Accuracy: ", accuracy)
# Out:
# F1 Score:  0.8064737884476054
# Accuracy:  0.7992720265496199

# %% [markdown]
# max_depth=None ,learning_rate= 0.1
# F1 Score:  0.7872191455289301
# Accuracy:  0.77636227384648337

# %% [markdown]
# ### SAUVEGARDE DU MODELE

# %%
from joblib import dump
dump(pipeline, ds.get_RACINE_SAUVEGARDE() +'XGB_TfIdf.joblib')
# Out:
# ['E:/Manuel/PROJET/Rakuten_Text_Classification_ML/fichiers/XGB_TfIdf.joblib']

# %% [markdown]
# ### RECUPERATION DU MODELE

# %%
from joblib import load
pipeline = load(ds.get_RACINE_SAUVEGARDE() + 'XGB_TfIdf.joblib')

# %%
total=(y_pred  ==  y_test)

# %%
total.value_counts()
# Out:
# prdtypecode
# True     14932
# False     3750
# Name: count, dtype: int64

# %%
df_test = X_test_avant.merge(y_test_avant,on='Unnamed: 0',how='inner')
df_test['predict']=y_pred
df_test.head()
# Out:
#    Unnamed: 0                                        designation  \
# 0       48911                         Coffret 5 Pièces Peppa Pig
# 1       22412  Jacobs Lungo 8 Intenso Capsules De Café Compat...
# 2       19061  Eon Altar: Episode 2 - Whispers In The Catacom...
# 3       26343                                        D - Livre 1
# 4       67827  Tommee Tippee - 82037101 - Sangenic - Lot De 6...
#
#                                          description   productid     imageid  \
# 0  <p>Vaisselle pour le repas des tout-petits fab...  3900805892  1261630470
# 1  Ce lungo se caractérise par la torréfaction pr...  4056000876  1282290576
# 2  <div> <p> <strong>NOTE :</strong> un compte St...  2017625778  1120710502
# 3  Quand un jeune homme se retrouve projet&eacute...   688661390  1061771602
# 4  <br>Nouvelle recharge Tomme Tippee compatible ...   304796550   996077810
#
#   PAYS_LANGUE                                     design_descrip  \
# 0          fr  Coffret 5 Pièces Peppa Pig <p>Vaisselle pour l...
# 1          fr  Jacobs Lungo 8 Intenso Capsules De Café Compat...
# 2          fr  Eon Altar: Episode 2 - Whispers In The Catacom...
# 3          fr  D - Livre 1 Quand un jeune homme se retrouve p...
# 4          fr  Tommee Tippee - 82037101 - Sangenic - Lot De 6...
#
#                                              phrases  prdtypecode  predict
# 0  [coffret, pièces, peppa, pig, vaisselle, repas...         1320     1320
# 1  [jacobs, lungo, intenso, capsules, café, compa...         1940     1940
# 2  [eon, altar, episode, whispers, catacombs, ext...         2905     2905
# 3  [livre, jeune, homme, retrouve, projet, monde,...         2705     2705
# 4  [tommee, tippee, 82037101, sangenic, lot, nouv...         1320     1320

# %% [markdown]
# ### Tableau des repartitions des **classes prédites** pour chaque **classe réelle**

# %%
for c in Lcat:
    print(c,'   ------   ', catdict[c] )
    print(df_test[df_test['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 10    ------    livres
# predict
# 10      0.751825
# 2403    0.074453
# 2280    0.072993
# 2705    0.035036
# 40      0.024818
# Name: proportion, dtype: float64
# 40    ------    jeux video pour pc et consoles
# predict
# 40      0.576087
# 10      0.193841
# 50      0.059783
# 2462    0.027174
# 1281    0.025362
# Name: proportion, dtype: float64
# 50    ------     accesoires jeux video
# predict
# 50      0.800000
# 2462    0.056757
# 40      0.027027
# 10      0.027027
# 1140    0.021622
# Name: proportion, dtype: float64
# 60    ------    consoles de jeux video
# predict
# 60      0.808743
# 50      0.081967
# 2462    0.038251
# 40      0.032787
# 1281    0.016393
# Name: proportion, dtype: float64
# 1140    ------    produits derives “geeks” et figurines
# predict
# 1140    0.715986
# 10      0.091837
# 1280    0.045918
# 2280    0.035714
# 1160    0.020408
# Name: proportion, dtype: float64
# 1160    ------    cartes collectionables
# predict
# 1160    0.882759
# 10      0.079310
# 2280    0.009195
# 1281    0.006897
# 2403    0.005747
# Name: proportion, dtype: float64
# 1180    ------    figurines collectionables pour jeux de societe
# predict
# 1180    0.565476
# 10      0.142857
# 1281    0.065476
# 1140    0.059524
# 1280    0.059524
# Name: proportion, dtype: float64
# 1280    ------    jouets, peluches, poupees
# predict
# 1280    0.704949
# 1140    0.059757
# 10      0.057890
# 1281    0.043884
# 1320    0.020542
# Name: proportion, dtype: float64
# 1281    ------    jeux de societe/cartes
# predict
# 1281    0.584615
# 1280    0.193407
# 10      0.054945
# 40      0.026374
# 1140    0.021978
# Name: proportion, dtype: float64
# 1300    ------    Petites voitures (jouets) et maquettes
# predict
# 1300    0.925225
# 10      0.023423
# 1280    0.016216
# 2280    0.009910
# 1140    0.003604
# Name: proportion, dtype: float64
# 1301    ------    accesoires pour petis enfants/bebes et mobilier de jeu (flechettes, billard, babyfoot)
# predict
# 1301    0.898876
# 2522    0.016854
# 1280    0.011236
# 40      0.011236
# 1320    0.011236
# Name: proportion, dtype: float64
# 1302    ------    jeux d'exterieur
# predict
# 1302    0.744526
# 1280    0.054745
# 10      0.038321
# 1281    0.027372
# 2582    0.023723
# Name: proportion, dtype: float64
# 1320    ------    sacs pour femmes et accesore petite enfance
# predict
# 1320    0.725105
# 10      0.079944
# 1280    0.044881
# 1560    0.032258
# 2060    0.028050
# Name: proportion, dtype: float64
# 1560    ------    Mobilier et produits decoration/rangement pour la maison
# predict
# 1560    0.821685
# 2060    0.063620
# 2582    0.026882
# 1920    0.023297
# 1320    0.014337
# Name: proportion, dtype: float64
# 1920    ------    linge de maison (cousins, rideaux, serviettes, nappes, draps)
# predict
# 1920    0.923970
# 2060    0.028511
# 1560    0.020063
# 1320    0.008448
# 2582    0.004224
# Name: proportion, dtype: float64
# 1940    ------    nouriture (cafes,infusions,conserves, epices,etc)
# predict
# 1940    0.785311
# 10      0.090395
# 2060    0.022599
# 2280    0.022599
# 2403    0.016949
# Name: proportion, dtype: float64
# 2060    ------    lampes et accesoires decoration pour maison
# predict
# 2060    0.818761
# 1920    0.040984
# 1560    0.040073
# 2582    0.020947
# 2585    0.014572
# Name: proportion, dtype: float64
# 2220    ------    accesoires mascots/pets
# predict
# 2220    0.773481
# 2060    0.038674
# 10      0.038674
# 1320    0.027624
# 1560    0.022099
# Name: proportion, dtype: float64
# 2280    ------    magazines
# predict
# 2280    0.753582
# 10      0.163324
# 2403    0.040115
# 2705    0.012416
# 1160    0.005731
# Name: proportion, dtype: float64
# 2403    ------    livres et bds
# predict
# 2403    0.697143
# 10      0.139048
# 2280    0.098095
# 2522    0.015238
# 1160    0.011429
# Name: proportion, dtype: float64
# 2462    ------    consoles de jeux video et jeux videos
# predict
# 2462    0.706070
# 50      0.076677
# 40      0.057508
# 10      0.047923
# 1160    0.025559
# Name: proportion, dtype: float64
# 2522    ------    produits de papeterie et rangement bureau
# predict
# 2522    0.881603
# 10      0.025501
# 2280    0.015483
# 2403    0.010929
# 1280    0.009107
# Name: proportion, dtype: float64
# 2582    ------    mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
# predict
# 2582    0.722807
# 1560    0.066667
# 2060    0.066667
# 2585    0.049123
# 1920    0.019298
# Name: proportion, dtype: float64
# 2583    ------    accesoires de piscine
# predict
# 2583    0.962600
# 10      0.009350
# 2060    0.005788
# 1302    0.004007
# 2585    0.004007
# Name: proportion, dtype: float64
# 2585    ------    outillage et accesoires pour jardinage
# predict
# 2585    0.755920
# 2060    0.051002
# 1560    0.038251
# 10      0.030965
# 2582    0.027322
# Name: proportion, dtype: float64
# 2705    ------    bds et livres
# predict
# 2705    0.622735
# 10      0.276771
# 2403    0.036244
# 2280    0.036244
# 40      0.008237
# Name: proportion, dtype: float64
# 2905    ------    Jeu En téléchargement
# predict
# 2905    0.994792
# 10      0.005208
# Name: proportion, dtype: float64

# %% [markdown]
# ### Tableau croisé

# %%
df_cross=pd.crosstab(df_test['prdtypecode'], df_test['predict'],normalize='index')
df_cross
# Out:
# predict          10        40        50        60        1140      1160  \
# prdtypecode
# 10           0.751825  0.024818  0.000000  0.000000  0.001460  0.005839
# 40           0.193841  0.576087  0.059783  0.001812  0.014493  0.007246
# 50           0.027027  0.027027  0.800000  0.002703  0.021622  0.000000
# 60           0.005464  0.032787  0.081967  0.808743  0.000000  0.000000
# 1140         0.091837  0.018707  0.011905  0.000000  0.715986  0.020408
# 1160         0.079310  0.003448  0.000000  0.000000  0.002299  0.882759
# 1180         0.142857  0.011905  0.011905  0.000000  0.059524  0.017857
# 1280         0.057890  0.012138  0.002801  0.000934  0.059757  0.004669
# 1281         0.054945  0.026374  0.000000  0.000000  0.021978  0.017582
# 1300         0.023423  0.003604  0.000901  0.000000  0.003604  0.001802
# 1301         0.005618  0.011236  0.000000  0.000000  0.000000  0.000000
# 1302         0.038321  0.001825  0.000000  0.000000  0.001825  0.000000
# 1320         0.079944  0.000000  0.001403  0.000000  0.007013  0.000000
# 1560         0.008065  0.000896  0.001792  0.000000  0.000896  0.000000
# 1920         0.001056  0.000000  0.000000  0.000000  0.000000  0.000000
# 1940         0.090395  0.000000  0.000000  0.000000  0.000000  0.000000
# 2060         0.012750  0.000000  0.000000  0.000000  0.003643  0.000000
# 2220         0.038674  0.000000  0.000000  0.000000  0.000000  0.000000
# 2280         0.163324  0.005731  0.000000  0.000000  0.002865  0.005731
# 2403         0.139048  0.005714  0.000000  0.000000  0.007619  0.011429
# 2462         0.047923  0.057508  0.076677  0.015974  0.012780  0.025559
# 2522         0.025501  0.002732  0.000911  0.000000  0.002732  0.008197
# 2582         0.012281  0.000000  0.000000  0.000000  0.000000  0.000000
# 2583         0.009350  0.000890  0.000000  0.000000  0.002226  0.000000
# 2585         0.030965  0.001821  0.000000  0.000000  0.005464  0.000000
# 2705         0.276771  0.008237  0.000000  0.000000  0.001647  0.000000
# 2905         0.005208  0.000000  0.000000  0.000000  0.000000  0.000000
#
# predict          1180      1280      1281      1300      1301      1302  \
# prdtypecode
# 10           0.001460  0.007299  0.002920  0.002920  0.000000  0.000000
# 40           0.000000  0.023551  0.025362  0.003623  0.000000  0.003623
# 50           0.000000  0.005405  0.005405  0.000000  0.000000  0.000000
# 60           0.005464  0.005464  0.016393  0.000000  0.000000  0.000000
# 1140         0.010204  0.045918  0.006803  0.005102  0.000000  0.003401
# 1160         0.002299  0.001149  0.006897  0.001149  0.000000  0.000000
# 1180         0.565476  0.059524  0.065476  0.011905  0.000000  0.000000
# 1280         0.001867  0.704949  0.043884  0.015873  0.000934  0.020542
# 1281         0.006593  0.193407  0.584615  0.002198  0.002198  0.013187
# 1300         0.001802  0.016216  0.001802  0.925225  0.000000  0.000901
# 1301         0.000000  0.011236  0.005618  0.005618  0.898876  0.011236
# 1302         0.000000  0.054745  0.027372  0.001825  0.001825  0.744526
# 1320         0.000000  0.044881  0.001403  0.001403  0.000000  0.007013
# 1560         0.000000  0.006272  0.000000  0.000896  0.000000  0.000000
# 1920         0.000000  0.004224  0.001056  0.000000  0.000000  0.000000
# 1940         0.000000  0.011299  0.000000  0.000000  0.000000  0.000000
# 2060         0.000000  0.012750  0.000911  0.000911  0.000000  0.001821
# 2220         0.000000  0.011050  0.000000  0.000000  0.000000  0.000000
# 2280         0.000955  0.002865  0.000955  0.004776  0.000000  0.000000
# 2403         0.000952  0.005714  0.002857  0.002857  0.000000  0.000000
# 2462         0.000000  0.012780  0.012780  0.006390  0.000000  0.000000
# 2522         0.000000  0.009107  0.003643  0.001821  0.000000  0.001821
# 2582         0.000000  0.003509  0.001754  0.003509  0.000000  0.003509
# 2583         0.000000  0.000890  0.000000  0.000890  0.000000  0.004007
# 2585         0.000000  0.005464  0.001821  0.000000  0.000000  0.005464
# 2705         0.000000  0.001647  0.004942  0.000000  0.000000  0.001647
# 2905         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# predict          1320      1560      1920      1940      2060      2220  \
# prdtypecode
# 10           0.002920  0.000000  0.000000  0.000000  0.000000  0.000000
# 40           0.001812  0.001812  0.000000  0.001812  0.001812  0.000000
# 50           0.000000  0.021622  0.002703  0.000000  0.010811  0.000000
# 60           0.005464  0.000000  0.000000  0.000000  0.000000  0.000000
# 1140         0.003401  0.000000  0.003401  0.000000  0.006803  0.000000
# 1160         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1180         0.000000  0.005952  0.000000  0.000000  0.005952  0.000000
# 1280         0.020542  0.004669  0.000934  0.000934  0.012138  0.002801
# 1281         0.002198  0.002198  0.000000  0.000000  0.013187  0.000000
# 1300         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1301         0.011236  0.005618  0.000000  0.000000  0.000000  0.000000
# 1302         0.014599  0.007299  0.000000  0.000000  0.009124  0.003650
# 1320         0.725105  0.032258  0.019635  0.004208  0.028050  0.001403
# 1560         0.014337  0.821685  0.023297  0.001792  0.063620  0.000000
# 1920         0.008448  0.020063  0.923970  0.000000  0.028511  0.000000
# 1940         0.011299  0.011299  0.000000  0.785311  0.022599  0.000000
# 2060         0.013661  0.040073  0.040984  0.003643  0.818761  0.000000
# 2220         0.027624  0.022099  0.011050  0.005525  0.038674  0.773481
# 2280         0.001910  0.000000  0.000000  0.000000  0.000000  0.000955
# 2403         0.000952  0.000000  0.000000  0.000000  0.000000  0.000952
# 2462         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2522         0.003643  0.009107  0.000911  0.000911  0.008197  0.000911
# 2582         0.008772  0.066667  0.019298  0.000000  0.066667  0.005263
# 2583         0.000890  0.000445  0.000000  0.000445  0.005788  0.000000
# 2585         0.009107  0.038251  0.003643  0.001821  0.051002  0.003643
# 2705         0.003295  0.000000  0.000000  0.001647  0.000000  0.000000
# 2905         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# predict          2280      2403      2462      2522      2582      2583  \
# prdtypecode
# 10           0.072993  0.074453  0.004380  0.010219  0.000000  0.000000
# 40           0.023551  0.014493  0.027174  0.001812  0.000000  0.000000
# 50           0.000000  0.002703  0.056757  0.005405  0.002703  0.000000
# 60           0.000000  0.000000  0.038251  0.000000  0.000000  0.000000
# 1140         0.035714  0.011905  0.001701  0.005102  0.000000  0.000000
# 1160         0.009195  0.005747  0.001149  0.001149  0.000000  0.000000
# 1180         0.005952  0.011905  0.005952  0.005952  0.000000  0.005952
# 1280         0.008403  0.005602  0.000934  0.008403  0.002801  0.003735
# 1281         0.013187  0.006593  0.010989  0.008791  0.000000  0.002198
# 1300         0.009910  0.002703  0.000000  0.000901  0.002703  0.001802
# 1301         0.005618  0.000000  0.000000  0.016854  0.000000  0.005618
# 1302         0.012774  0.009124  0.001825  0.009124  0.023723  0.020073
# 1320         0.011220  0.007013  0.001403  0.009818  0.012623  0.000000
# 1560         0.002688  0.000896  0.000000  0.008065  0.026882  0.003584
# 1920         0.001056  0.003168  0.000000  0.001056  0.004224  0.000000
# 1940         0.022599  0.016949  0.000000  0.011299  0.005650  0.005650
# 2060         0.004554  0.000000  0.000000  0.005464  0.020947  0.002732
# 2220         0.005525  0.005525  0.000000  0.016575  0.016575  0.016575
# 2280         0.753582  0.040115  0.000955  0.001910  0.000000  0.000955
# 2403         0.098095  0.697143  0.000952  0.015238  0.000000  0.000000
# 2462         0.000000  0.015974  0.706070  0.003195  0.000000  0.003195
# 2522         0.015483  0.010929  0.000000  0.881603  0.001821  0.000911
# 2582         0.003509  0.003509  0.000000  0.014035  0.722807  0.014035
# 2583         0.003117  0.000445  0.000000  0.001781  0.002226  0.962600
# 2585         0.010929  0.001821  0.000000  0.021858  0.027322  0.023679
# 2705         0.036244  0.036244  0.000000  0.004942  0.000000  0.000000
# 2905         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# predict          2585      2705      2905
# prdtypecode
# 10           0.001460  0.035036  0.000000
# 40           0.000000  0.014493  0.001812
# 50           0.002703  0.002703  0.002703
# 60           0.000000  0.000000  0.000000
# 1140         0.001701  0.000000  0.000000
# 1160         0.000000  0.003448  0.000000
# 1180         0.005952  0.000000  0.000000
# 1280         0.001867  0.000000  0.000000
# 1281         0.000000  0.017582  0.000000
# 1300         0.001802  0.000901  0.000000
# 1301         0.005618  0.000000  0.000000
# 1302         0.012774  0.001825  0.001825
# 1320         0.001403  0.002805  0.000000
# 1560         0.014337  0.000000  0.000000
# 1920         0.001056  0.002112  0.000000
# 1940         0.000000  0.005650  0.000000
# 2060         0.014572  0.001821  0.000000
# 2220         0.011050  0.000000  0.000000
# 2280         0.000000  0.012416  0.000000
# 2403         0.000952  0.009524  0.000000
# 2462         0.000000  0.003195  0.000000
# 2522         0.008197  0.000911  0.000000
# 2582         0.049123  0.001754  0.000000
# 2583         0.004007  0.000000  0.000000
# 2585         0.755920  0.000000  0.000000
# 2705         0.000000  0.622735  0.000000
# 2905         0.000000  0.000000  0.994792

# %% [markdown]
# ### Tableau des repartitions des **classes prédites** pour chaque **classe réelle** avec libellés.

# %%
for c in Lcat:
    print(c,'   ------   ', catdict[c])
    s = df_cross.loc[c].sort_values(ascending=False)[:5]
    for index, value in s.items():  # Utilisez items() au lieu de iteritems()
        print(f"  : {index},  : {np.round(value*100,2)} % , {catdict[index]}")
# Out:
# 10    ------    livres
#   : 10,  : 75.18 % , livres
#   : 2403,  : 7.45 % , livres et bds
#   : 2280,  : 7.3 % , magazines
#   : 2705,  : 3.5 % , bds et livres
#   : 40,  : 2.48 % , jeux video pour pc et consoles
# 40    ------    jeux video pour pc et consoles
#   : 40,  : 57.61 % , jeux video pour pc et consoles
#   : 10,  : 19.38 % , livres
#   : 50,  : 5.98 % ,  accesoires jeux video
#   : 2462,  : 2.72 % , consoles de jeux video et jeux videos
#   : 1281,  : 2.54 % , jeux de societe/cartes
# 50    ------     accesoires jeux video
#   : 50,  : 80.0 % ,  accesoires jeux video
#   : 2462,  : 5.68 % , consoles de jeux video et jeux videos
#   : 10,  : 2.7 % , livres
#   : 40,  : 2.7 % , jeux video pour pc et consoles
#   : 1560,  : 2.16 % , Mobilier et produits decoration/rangement pour la maison
# 60    ------    consoles de jeux video
#   : 60,  : 80.87 % , consoles de jeux video
#   : 50,  : 8.2 % ,  accesoires jeux video
#   : 2462,  : 3.83 % , consoles de jeux video et jeux videos
#   : 40,  : 3.28 % , jeux video pour pc et consoles
#   : 1281,  : 1.64 % , jeux de societe/cartes
# 1140    ------    produits derives “geeks” et figurines
#   : 1140,  : 71.6 % , produits derives “geeks” et figurines
#   : 10,  : 9.18 % , livres
#   : 1280,  : 4.59 % , jouets, peluches, poupees
#   : 2280,  : 3.57 % , magazines
#   : 1160,  : 2.04 % , cartes collectionables
# 1160    ------    cartes collectionables
#   : 1160,  : 88.28 % , cartes collectionables
#   : 10,  : 7.93 % , livres
#   : 2280,  : 0.92 % , magazines
#   : 1281,  : 0.69 % , jeux de societe/cartes
#   : 2403,  : 0.57 % , livres et bds
# 1180    ------    figurines collectionables pour jeux de societe
#   : 1180,  : 56.55 % , figurines collectionables pour jeux de societe
#   : 10,  : 14.29 % , livres
#   : 1281,  : 6.55 % , jeux de societe/cartes
#   : 1140,  : 5.95 % , produits derives “geeks” et figurines
#   : 1280,  : 5.95 % , jouets, peluches, poupees
# 1280    ------    jouets, peluches, poupees
#   : 1280,  : 70.49 % , jouets, peluches, poupees
#   : 1140,  : 5.98 % , produits derives “geeks” et figurines
#   : 10,  : 5.79 % , livres
#   : 1281,  : 4.39 % , jeux de societe/cartes
#   : 1320,  : 2.05 % , sacs pour femmes et accesore petite enfance
# 1281    ------    jeux de societe/cartes
#   : 1281,  : 58.46 % , jeux de societe/cartes
#   : 1280,  : 19.34 % , jouets, peluches, poupees
#   : 10,  : 5.49 % , livres
#   : 40,  : 2.64 % , jeux video pour pc et consoles
#   : 1140,  : 2.2 % , produits derives “geeks” et figurines
# 1300    ------    Petites voitures (jouets) et maquettes
#   : 1300,  : 92.52 % , Petites voitures (jouets) et maquettes
#   : 10,  : 2.34 % , livres
#   : 1280,  : 1.62 % , jouets, peluches, poupees
#   : 2280,  : 0.99 % , magazines
#   : 1140,  : 0.36 % , produits derives “geeks” et figurines
# 1301    ------    accesoires pour petis enfants/bebes et mobilier de jeu (flechettes, billard, babyfoot)
#   : 1301,  : 89.89 % , accesoires pour petis enfants/bebes et mobilier de jeu (flechettes, billard, babyfoot)
#   : 2522,  : 1.69 % , produits de papeterie et rangement bureau
#   : 40,  : 1.12 % , jeux video pour pc et consoles
#   : 1280,  : 1.12 % , jouets, peluches, poupees
#   : 1320,  : 1.12 % , sacs pour femmes et accesore petite enfance
# 1302    ------    jeux d'exterieur
#   : 1302,  : 74.45 % , jeux d'exterieur
#   : 1280,  : 5.47 % , jouets, peluches, poupees
#   : 10,  : 3.83 % , livres
#   : 1281,  : 2.74 % , jeux de societe/cartes
#   : 2582,  : 2.37 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
# 1320    ------    sacs pour femmes et accesore petite enfance
#   : 1320,  : 72.51 % , sacs pour femmes et accesore petite enfance
#   : 10,  : 7.99 % , livres
#   : 1280,  : 4.49 % , jouets, peluches, poupees
#   : 1560,  : 3.23 % , Mobilier et produits decoration/rangement pour la maison
#   : 2060,  : 2.81 % , lampes et accesoires decoration pour maison
# 1560    ------    Mobilier et produits decoration/rangement pour la maison
#   : 1560,  : 82.17 % , Mobilier et produits decoration/rangement pour la maison
#   : 2060,  : 6.36 % , lampes et accesoires decoration pour maison
#   : 2582,  : 2.69 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1920,  : 2.33 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 1320,  : 1.43 % , sacs pour femmes et accesore petite enfance
# 1920    ------    linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 1920,  : 92.4 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 2060,  : 2.85 % , lampes et accesoires decoration pour maison
#   : 1560,  : 2.01 % , Mobilier et produits decoration/rangement pour la maison
#   : 1320,  : 0.84 % , sacs pour femmes et accesore petite enfance
#   : 2582,  : 0.42 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
# 1940    ------    nouriture (cafes,infusions,conserves, epices,etc)
#   : 1940,  : 78.53 % , nouriture (cafes,infusions,conserves, epices,etc)
#   : 10,  : 9.04 % , livres
#   : 2280,  : 2.26 % , magazines
#   : 2060,  : 2.26 % , lampes et accesoires decoration pour maison
#   : 2403,  : 1.69 % , livres et bds
# 2060    ------    lampes et accesoires decoration pour maison
#   : 2060,  : 81.88 % , lampes et accesoires decoration pour maison
#   : 1920,  : 4.1 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 1560,  : 4.01 % , Mobilier et produits decoration/rangement pour la maison
#   : 2582,  : 2.09 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2585,  : 1.46 % , outillage et accesoires pour jardinage
# 2220    ------    accesoires mascots/pets
#   : 2220,  : 77.35 % , accesoires mascots/pets
#   : 10,  : 3.87 % , livres
#   : 2060,  : 3.87 % , lampes et accesoires decoration pour maison
#   : 1320,  : 2.76 % , sacs pour femmes et accesore petite enfance
#   : 1560,  : 2.21 % , Mobilier et produits decoration/rangement pour la maison
# 2280    ------    magazines
#   : 2280,  : 75.36 % , magazines
#   : 10,  : 16.33 % , livres
#   : 2403,  : 4.01 % , livres et bds
#   : 2705,  : 1.24 % , bds et livres
#   : 40,  : 0.57 % , jeux video pour pc et consoles
# 2403    ------    livres et bds
#   : 2403,  : 69.71 % , livres et bds
#   : 10,  : 13.9 % , livres
#   : 2280,  : 9.81 % , magazines
#   : 2522,  : 1.52 % , produits de papeterie et rangement bureau
#   : 1160,  : 1.14 % , cartes collectionables
# 2462    ------    consoles de jeux video et jeux videos
#   : 2462,  : 70.61 % , consoles de jeux video et jeux videos
#   : 50,  : 7.67 % ,  accesoires jeux video
#   : 40,  : 5.75 % , jeux video pour pc et consoles
#   : 10,  : 4.79 % , livres
#   : 1160,  : 2.56 % , cartes collectionables
# 2522    ------    produits de papeterie et rangement bureau
#   : 2522,  : 88.16 % , produits de papeterie et rangement bureau
#   : 10,  : 2.55 % , livres
#   : 2280,  : 1.55 % , magazines
#   : 2403,  : 1.09 % , livres et bds
#   : 1280,  : 0.91 % , jouets, peluches, poupees
# 2582    ------    mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2582,  : 72.28 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1560,  : 6.67 % , Mobilier et produits decoration/rangement pour la maison
#   : 2060,  : 6.67 % , lampes et accesoires decoration pour maison
#   : 2585,  : 4.91 % , outillage et accesoires pour jardinage
#   : 1920,  : 1.93 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
# 2583    ------    accesoires de piscine
#   : 2583,  : 96.26 % , accesoires de piscine
#   : 10,  : 0.93 % , livres
#   : 2060,  : 0.58 % , lampes et accesoires decoration pour maison
#   : 2585,  : 0.4 % , outillage et accesoires pour jardinage
#   : 1302,  : 0.4 % , jeux d'exterieur
# 2585    ------    outillage et accesoires pour jardinage
#   : 2585,  : 75.59 % , outillage et accesoires pour jardinage
#   : 2060,  : 5.1 % , lampes et accesoires decoration pour maison
#   : 1560,  : 3.83 % , Mobilier et produits decoration/rangement pour la maison
#   : 10,  : 3.1 % , livres
#   : 2582,  : 2.73 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
# 2705    ------    bds et livres
#   : 2705,  : 62.27 % , bds et livres
#   : 10,  : 27.68 % , livres
#   : 2403,  : 3.62 % , livres et bds
#   : 2280,  : 3.62 % , magazines
#   : 40,  : 0.82 % , jeux video pour pc et consoles
# 2905    ------    Jeu En téléchargement
#   : 2905,  : 99.48 % , Jeu En téléchargement
#   : 10,  : 0.52 % , livres
#   : 50,  : 0.0 % ,  accesoires jeux video
#   : 1940,  : 0.0 % , nouriture (cafes,infusions,conserves, epices,etc)
#   : 2705,  : 0.0 % , bds et livres

# %% [markdown]
# ### Rapport de classification

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred ))
# Out:
#               precision    recall  f1-score   support
#
#           10       0.32      0.75      0.45       685
#           40       0.72      0.58      0.64       552
#           50       0.77      0.80      0.78       370
#           60       0.95      0.81      0.87       183
#         1140       0.74      0.72      0.73       588
#         1160       0.91      0.88      0.90       870
#         1180       0.83      0.57      0.67       168
#         1280       0.72      0.70      0.71      1071
#         1281       0.68      0.58      0.63       455
#         1300       0.95      0.93      0.94      1110
#         1301       0.98      0.90      0.94       178
#         1302       0.87      0.74      0.80       548
#         1320       0.83      0.73      0.77       713
#         1560       0.83      0.82      0.83      1116
#         1920       0.89      0.92      0.91       947
#         1940       0.90      0.79      0.84       177
#         2060       0.78      0.82      0.80      1098
#         2220       0.91      0.77      0.84       181
#         2280       0.72      0.75      0.74      1047
#         2403       0.79      0.70      0.74      1050
#         2462       0.79      0.71      0.75       313
#         2522       0.90      0.88      0.89      1098
#         2582       0.79      0.72      0.75       570
#         2583       0.98      0.96      0.97      2246
#         2585       0.81      0.76      0.78       549
#         2705       0.83      0.62      0.71       607
#         2905       0.98      0.99      0.99       192
#
#     accuracy                           0.80     18682
#    macro avg       0.82      0.77      0.79     18682
# weighted avg       0.82      0.80      0.81     18682

# %% [markdown]
# ### Matrice de confusion

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred )
print(cm[:10,:10])
print('*************************************************')
print(cm[10:20,10:20])
print('*************************************************')
print(cm[20:,20:])
# Out:
# [[ 515   17    0    0    1    4    1    5    2    2]
#  [ 107  318   33    1    8    4    0   13   14    2]
#  [  10   10  296    1    8    0    0    2    2    0]
#  [   1    6   15  148    0    0    1    1    3    0]
#  [  54   11    7    0  421   12    6   27    4    3]
#  [  69    3    0    0    2  768    2    1    6    1]
#  [  24    2    2    0   10    3   95   10   11    2]
#  [  62   13    3    1   64    5    2  755   47   17]
#  [  25   12    0    0   10    8    3   88  266    1]
#  [  26    4    1    0    4    2    2   18    2 1027]]
# *************************************************
# [[160   2   2   1   0   0   0   0   1   0]
#  [  1 408   8   4   0   0   5   2   7   5]
#  [  0   5 517  23  14   3  20   1   8   5]
#  [  0   0  16 917  26   2  71   0   3   1]
#  [  0   0   8  19 875   0  27   0   1   3]
#  [  0   0   2   2   0 139   4   0   4   3]
#  [  0   2  15  44  45   4 899   0   5   0]
#  [  0   0   5   4   2   1   7 140   1   1]
#  [  0   0   2   0   0   0   0   1 789  42]
#  [  0   0   1   0   0   0   0   1 103 732]]
# *************************************************
# [[ 221    1    0    1    0    1    0]
#  [   0  968    2    1    9    1    0]
#  [   0    8  412    8   28    1    0]
#  [   0    4    5 2162    9    0    0]
#  [   0   12   15   13  415    0    0]
#  [   0    3    0    0    0  378    0]
#  [   0    0    0    0    0    0  191]]

# %%
fig, ax = plt.subplots(figsize=(10,10))
cm_normalized = cm.astype('float') / (cm.sum(axis=1)[:, np.newaxis])
#cm_normalized=cm.div(cm.sum(axis=1), axis=0)
cax = ax.matshow(cm_normalized, cmap='Reds')
plt.xticks(range(27),catdict,rotation=90)
plt.yticks(range(27),catdict,rotation=0)
plt.show()

# %% [markdown]
# ## Etude des catégories 10 ; 2280 ; 2403 ; 2705

# %%
df_livres=df_test[df_test['prdtypecode'].isin([10,2280,2403,2705])]
vectorizer=pipeline.named_steps['tfidf']
df_livres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3389 entries, 3 to 18679
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      3389 non-null   int64
#  1   designation     3389 non-null   object
#  2   description     569 non-null    object
#  3   productid       3389 non-null   int64
#  4   imageid         3389 non-null   int64
#  5   PAYS_LANGUE     3389 non-null   object
#  6   design_descrip  3389 non-null   object
#  7   phrases         3389 non-null   object
#  8   prdtypecode     3389 non-null   int64
#  9   predict         3389 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 291.2+ KB

# %% [markdown]
# ### Tableau des repartitions des **classes predites** pour chaque `classe réelle`

# %%
for c in [10,2280,2403,2705]:
    print(c,'   ------   ', catdict[c] )
    print(df_livres[df_livres['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 10    ------    livres
# predict
# 10      0.751825
# 2403    0.074453
# 2280    0.072993
# 2705    0.035036
# 40      0.024818
# Name: proportion, dtype: float64
# 2280    ------    magazines
# predict
# 2280    0.753582
# 10      0.163324
# 2403    0.040115
# 2705    0.012416
# 1160    0.005731
# Name: proportion, dtype: float64
# 2403    ------    livres et bds
# predict
# 2403    0.697143
# 10      0.139048
# 2280    0.098095
# 2522    0.015238
# 1160    0.011429
# Name: proportion, dtype: float64
# 2705    ------    bds et livres
# predict
# 2705    0.622735
# 10      0.276771
# 2403    0.036244
# 2280    0.036244
# 40      0.008237
# Name: proportion, dtype: float64

# %% [markdown]
# ### Les 10 mots ayant le **scores TF-IDF** les plus élévés et ceux des rangs de 76 à 80.
# Ces scores aident à identifier les mots qui sont importants dans un document particulier en tenant compte
# de leur fréquence dans ce document et de leur rareté dans l'ensemble du corpus.

# %%
Words = vectorizer.transform(df_livres['designation'])
#help(CountVectorizer)
words = vectorizer.get_feature_names_out()
word_counts = Words.sum(axis=0)
word_count_dict = dict(zip(words, word_counts.tolist()[0]))
#print(word_count_dict)
occurrences_triees = sorted(word_count_dict.items(), key=lambda x: x[1], reverse=True)[:80]
Dic_words={}
for item in occurrences_triees:
    #print(item[0], ":", item[1])
    Dic_words[item[0]]=item[1]
#print(Dic_words)
df_words=pd.DataFrame.from_dict(Dic_words, orient='index',columns=['Total'])
print(df_words.head(10))
print(df_words.tail())
# Out:
#               Total
# lot       93.297337
# tome      56.344146
# livres    51.999364
# 01        40.179128
# 10        38.497605
# 12        32.783278
# 11        30.922111
# france    30.095782
# revue     29.677567
# magazine  29.114804
#               Total
# piano      7.124548
# 24         7.036313
# avril      6.973697
# album      6.967048
# intégrale  6.873213

# %% [markdown]
# ### Les 20 mots ayant le **scores TF-IDF** les plus élévés .

# %%
df_total_livres=df_words
words = vectorizer.get_feature_names_out()
for c in [10,2705,2280,2403]:
    X_words = vectorizer.transform(df_livres[df_livres['prdtypecode']==c] ['designation'])
    word_counts = X_words.sum(axis=0)
    word_count_dict = dict(zip(words, word_counts.tolist()[0]))
    occurrences_triees = sorted(word_count_dict.items(), key=lambda x: x[1], reverse=True)[:20]
    Dic_words={}
    for item in occurrences_triees:
        Dic_words[item[0]]=item[1]
    df_words_X=pd.DataFrame.from_dict(Dic_words, orient='index',columns=[str(c)])
    df_total_livres=df_total_livres.join(df_words_X)
df_total_livres.head(20)
# Out:
#                 Total         10       2705       2280       2403
# lot         93.297337        NaN        NaN        NaN  92.158471
# tome        56.344146  11.650113  21.940619        NaN  21.325055
# livres      51.999364        NaN        NaN        NaN  50.275812
# 01          40.179128        NaN        NaN  36.974804        NaN
# 10          38.497605        NaN        NaN  19.536979  16.409545
# 12          32.783278        NaN        NaN  19.277957  12.077328
# 11          30.922111   3.646027        NaN  20.438734        NaN
# france      30.095782   3.912862        NaN  14.726065   9.712943
# revue       29.677567        NaN        NaN  16.593297  11.865593
# magazine    29.114804        NaN        NaN  20.411596        NaN
# tomes       28.600826        NaN        NaN        NaN  27.645146
# volumes     25.446771        NaN        NaN        NaN  24.227733
# histoire    24.697639   5.927844        NaN        NaN  11.732009
# journal     24.205332   2.485323        NaN  15.421089        NaN
# vie         21.952814   3.263573   7.939092   7.403071        NaN
# monde       20.874603        NaN   5.277999   8.893445        NaN
# collection  19.138294        NaN        NaN        NaN  15.550607
# 09          17.751484        NaN        NaN  17.751484        NaN
# revues      17.625920        NaN        NaN        NaN  17.391009
# paris       17.476187        NaN   3.879804  10.305815        NaN

# %% [markdown]
# ### Heatmap couleur Rouge foncée : fréquence très élévée
# couleur Bleu foncée : fréquance très basse
# couleur Blanche : NaN

# %%
fig, ax = plt.subplots(figsize=(2,20))
cax = ax.matshow(df_total_livres.iloc[0:40], cmap = 'coolwarm')
plt.xticks(range(5),('total','10','2705','2280','2403'),rotation=45)
plt.yticks(range(40),df_total_livres.iloc[0:40].index,rotation=0)
plt.show()

# %% [markdown]
# ## Etude des catégories 1280,1281

# %%
df_jouets=df_test[df_test['prdtypecode'].isin([1280,1281])]

# %% [markdown]
# ### Tableau des repartitions des **classes predites** pour chaque `classe réelle`

# %%
for c in [1280,1281]:
    print(c,'   ------   ', catdict[c] )
    print(df_jouets[df_jouets['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 1280    ------    jouets, peluches, poupees
# predict
# 1280    0.704949
# 1140    0.059757
# 10      0.057890
# 1281    0.043884
# 1320    0.020542
# Name: proportion, dtype: float64
# 1281    ------    jeux de societe/cartes
# predict
# 1281    0.584615
# 1280    0.193407
# 10      0.054945
# 40      0.026374
# 1140    0.021978
# Name: proportion, dtype: float64

# %% [markdown]
# ### Les 10 mots ayant le **scores TF-IDF** les plus élévés et ceux des rangs de 76 à 80.
# Ces scores aident à identifier les mots qui sont importants dans un document particulier en tenant compte
# de leur fréquence dans ce document et de leur rareté dans l'ensemble du corpus.

# %%
Words = vectorizer.transform(df_jouets['designation'])
#help(CountVectorizer)
words = vectorizer.get_feature_names_out()
word_counts = Words.sum(axis=0)
word_count_dict = dict(zip(words, word_counts.tolist()[0]))
#print(word_count_dict)
occurrences_triees = sorted(word_count_dict.items(), key=lambda x: x[1], reverse=True)[:80]
Dic_words={}
for item in occurrences_triees:
    #print(item[0], ":", item[1])
    Dic_words[item[0]]=item[1]
#print(Dic_words)
df_words=pd.DataFrame.from_dict(Dic_words, orient='index',columns=['Total'])
print(df_words.head(10))
print(df_words.tail())
# Out:
#              Total
# enfants  45.267651
# jouet    37.558010
# peluche  35.140603
# jouets   34.989406
# toy      32.252619
# doudou   30.234269
# puzzle   27.056359
# jeu      23.825432
# bébé     21.655558
# cadeau   21.282932
#                   Total
# développement  5.803189
# boule          5.802947
# simulé         5.781250
# musique        5.724818
# jouer          5.718962

# %% [markdown]
# ### Les 20 mots ayant le **scores TF-IDF** les plus élévés .

# %%
df_total_jouets=df_words
words = vectorizer.get_feature_names_out()
for c in [1280,1281]:
    X_words = vectorizer.transform(df_jouets[df_jouets['prdtypecode']==c] ['designation'])
    word_counts = X_words.sum(axis=0)
    word_count_dict = dict(zip(words, word_counts.tolist()[0]))
    occurrences_triees = sorted(word_count_dict.items(), key=lambda x: x[1], reverse=True)[:20]
    Dic_words={}
    for item in occurrences_triees:
        Dic_words[item[0]]=item[1]
    df_words_X=pd.DataFrame.from_dict(Dic_words, orient='index',columns=[str(c)])
    df_total_jouets=df_total_jouets.join(df_words_X)
df_total_jouets.head(20)
# Out:
#              Total       1280       1281
# enfants  45.267651  33.080509  12.187142
# jouet    37.558010  29.292394   8.265616
# peluche  35.140603  32.579356        NaN
# jouets   34.989406  26.024941   8.964465
# toy      32.252619  22.019574  10.233046
# doudou   30.234269  30.234269        NaN
# puzzle   27.056359  22.612416   4.443943
# jeu      23.825432        NaN  19.169829
# bébé     21.655558  14.665426   6.990132
# cadeau   21.282932  15.821260   5.461672
# rc       20.587665  19.539490        NaN
# voiture  17.665365  15.301379        NaN
# game     16.973332        NaN  14.201457
# doll     16.902886  15.368207        NaN
# stress   14.992788   9.945964   5.046823
# baby     14.925936  13.489560        NaN
# slime    14.351219        NaN   7.479360
# poupée   14.285657  12.814163        NaN
# mini     14.269059        NaN        NaN
# modèle   13.781289  10.899263        NaN

# %% [markdown]
# ###**Heatmap**
# couleur Rouge foncée : fréquence très élévée
# couleur Bleu foncée : fréquance très basse
# couleur Blanche : NaN

# %%
fig, ax = plt.subplots(figsize=(2,20))
cax = ax.matshow(df_total_jouets.iloc[0:40], cmap = 'coolwarm')
plt.xticks(range(3),('total','1280','1281'),rotation=45)
plt.yticks(range(40),df_total_jouets.iloc[0:40].index,rotation=0)
plt.show()
